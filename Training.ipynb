# %%
import pandas as pd
import os
import numpy as np

# %%
df = pd.read_csv('data/birdclef-2021/train_metadata.csv')

# %% [markdown]
# ### Create some dictionaries to make data creation quicker

# %%
DATA_DIR = "data/birdclef-2021-parsed/train_short_audio"
class_names = os.listdir(DATA_DIR)
class_names.remove('noise')
class_name_to_id = {label:index for index, label in enumerate(class_names)}

filenames = df.filename
primary_label_list = df.primary_label
secondary_labels_list = df.secondary_labels

indices = range(len(filenames))
dict = {}
for filename, index, primary_label, secondary_labels in zip(filenames, indices, primary_label_list, secondary_labels_list):
    sec = json.loads(secondary_labels.replace('\'', '"'))
    [dict[]]
    print(sec)
    dict[filename] = (index, primary_label, sec)
# Out:
# ['amegfi']
# []
# []
# ['whwbec1']
# ['whwbec1']
# []
# []
# []
# []
# []
# []
# ['whevir', 'norcar', 'yebcha']
# []
# ['yebcha', 'woothr', 'reevir1', 'amecro', 'norcar', 'comyel']
# ['prowar', 'reshaw', 'norcar', 'tuftit']
# ['carwre', 'reevir1', 'norcar', 'rebwoo', 'carchi', 'whevir', 'reshaw', 'eastow']
# ['ovenbi1']
# []
# []
# []
# []
# ['banana', 'goftyr1', 'reevir1']
# []
# []
# ['carwre', 'norcar']
# ['norcar', 'reevir1']
# []
# ['carwre', 'rebwoo', 'norcar']
# ['grethr1', 'spvear1']
# ['tuftit', 'whevir', 'carwre', 'yebcha', 'indbun', 'amecro', 'buggna', 'norcar', 'reevir1', 'grbher3']
# ['andsol1', 'orbeup1']
# ['gbwwre1', 'goftyr1']
# []
# []
# []
# ['norpar', 'norcar', 'carwre', 'bnhcow', 'buggna', 'woothr']
# []
# []
# []
# ['norcar', 'buggna', 'rthhum']
# []
# []
# []
# []
# ['rudpig']
# []
# ['rutjac1']
# ['chbant1']
# ['woothr', 'norcar', 'chispa', 'rebwoo']
# []
# []
# []
# ['carwre', 'carchi', 'amered', 'moudov']
# []
# ['ovenbi1', 'amecro']
# []
# []
# []
# ...

# %% [markdown]
# ### Create arrays for data
# images_x is a list containing paths to images
#
# labels_x is a list containing (primary_label, secondary_labels), where primary_label is a number and secondary_labels is a list containing numbers

# %%
images_train = []
images_valid = []
images_test = []

labels_train = []
labels_valid = []
labels_test = []

# %%
for directory in os.listdir(DATA_DIR):
# Out:
# data/birdclef-2021-parsed/train_short_audio

# %%
os.listdir(DATA_DIR)
class_names
# Out:
# ['acafly',
#  'acowoo',
#  'aldfly',
#  'ameavo',
#  'amecro',
#  'amegfi',
#  'amekes',
#  'amepip',
#  'amered',
#  'amerob',
#  'amewig',
#  'amtspa',
#  'andsol1',
#  'annhum',
#  'astfly',
#  'azaspi1',
#  'babwar',
#  'baleag',
#  'balori',
#  'banana',
#  'banswa',
#  'banwre1',
#  'barant1',
#  'barswa',
#  'batpig1',
#  'bawswa1',
#  'bawwar',
#  'baywre1',
#  'bbwduc',
#  'bcnher',
#  'belkin1',
#  'belvir',
#  'bewwre',
#  'bkbmag1',
#  'bkbplo',
#  'bkbwar',
#  'bkcchi',
#  'bkhgro',
#  'bkmtou1',
#  'bknsti',
#  'blbgra1',
#  'blbthr1',
#  'blcjay1',
#  'blctan1',
#  'blhpar1',
#  'blkpho',
#  'blsspa1',
#  'blugrb1',
#  'blujay',
#  'bncfly',
#  'bnhcow',
#  'bobfly1',
#  'bongul',
#  'botgra',
#  'brbmot1',
#  'brbsol1',
#  'brcvir1',
#  'brebla',
#  'brncre',
#  'brnjay',
#  'brnthr',
#  'brratt1',
#  'brwhaw',
#  'brwpar1',
#  'btbwar',
#  'btnwar',
#  'btywar',
#  'bucmot2',
#  'buggna',
#  'bugtan',
#  'buhvir',
#  'bulori',
#  'burwar1',
#  'bushti',
# ...

# %%
for label in os.listdir(DATA_DIR):
    print(label)
# Out:
# acafly
# acowoo
# aldfly
# ameavo
# amecro
# amegfi
# amekes
# amepip
# amered
# amerob
# amewig
# amtspa
# andsol1
# annhum
# astfly
# azaspi1
# babwar
# baleag
# balori
# banana
# banswa
# banwre1
# barant1
# barswa
# batpig1
# bawswa1
# bawwar
# baywre1
# bbwduc
# bcnher
# belkin1
# belvir
# bewwre
# bkbmag1
# bkbplo
# bkbwar
# bkcchi
# bkhgro
# bkmtou1
# bknsti
# blbgra1
# blbthr1
# blcjay1
# blctan1
# blhpar1
# blkpho
# blsspa1
# blugrb1
# blujay
# bncfly
# bnhcow
# bobfly1
# bongul
# botgra
# brbmot1
# brbsol1
# brcvir1
# brebla
# brncre
# brnjay
# brnthr
# brratt1
# brwhaw
# brwpar1
# btbwar
# btnwar
# btywar
# bucmot2
# buggna
# bugtan
# buhvir
# bulori
# burwar1
# bushti
# butsal1
# buwtea
# cacgoo1
# cacwre
# calqua
# caltow
# cangoo
# canwar
# carchi
# carwre
# casfin
# caskin
# caster1
# casvir
# categr
# ccbfin
# cedwax
# chbant1
# chbchi
# chbwre1
# chcant2
# chispa
# chswar
# cinfly2
# clanut
# clcrob
# cliswa
# cobtan1
# cocwoo1
# cogdov
# colcha1
# coltro1
# comgol
# ...

# %%
filename = "XC6671.ogg"

# %%
import time
t0 = time.time()
for i in range(100):
    b = dict.get("XC6671.ogg")
print(time.time() - t0)
# Out:
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 131
# 0.00299072265625

# %%
df.columns
# Out:
# Index(['primary_label', 'secondary_labels', 'type', 'latitude', 'longitude',
#        'scientific_name', 'common_name', 'author', 'date', 'filename',
#        'license', 'rating', 'time', 'url'],
#       dtype='object')

# %%
dict['XC136287.ogg']
# Out:
# yebcha

# %%
dict
# Out:
# {'XC109605.ogg': (0, 'acafly', ['amegfi']),
#  'XC11209.ogg': (1, 'acafly', []),
#  'XC127032.ogg': (2, 'acafly', []),
#  'XC129974.ogg': (3, 'acafly', ['whwbec1']),
#  'XC129981.ogg': (4, 'acafly', ['whwbec1']),
#  'XC130056.ogg': (5, 'acafly', []),
#  'XC130133.ogg': (6, 'acafly', []),
#  'XC130140.ogg': (7, 'acafly', []),
#  'XC130750.ogg': (8, 'acafly', []),
#  'XC131193.ogg': (9, 'acafly', []),
#  'XC133047.ogg': (10, 'acafly', []),
#  'XC135020.ogg': (11, 'acafly', ['whevir', 'norcar', 'yebcha']),
#  'XC135121.ogg': (12, 'acafly', []),
#  'XC136287.ogg': (13,
#   'acafly',
#   ['yebcha', 'woothr', 'reevir1', 'amecro', 'norcar', 'comyel']),
#  'XC136290.ogg': (14, 'acafly', ['prowar', 'reshaw', 'norcar', 'tuftit']),
#  'XC136301.ogg': (15,
#   'acafly',
#   ['carwre',
#    'reevir1',
#    'norcar',
#    'rebwoo',
#    'carchi',
#    'whevir',
#    'reshaw',
#    'eastow']),
#  'XC137858.ogg': (16, 'acafly', ['ovenbi1']),
#  'XC137859.ogg': (17, 'acafly', []),
# ...

# %%
import json
json.loads(a)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-105-a762428118e6> in <module>
#       1 import json
# ----> 2 json.loads(a)
#
# c:\users\katane\appdata\local\programs\python\python38\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# c:\users\katane\appdata\local\programs\python\python38\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ...

# %%
a = "['gamqua', 'test']"
b = json.loads(a.replace('\'', '"'))

# %%
print(b[0])
# Out:
# gamqua

# %%
# Out:
# ''
# ''
